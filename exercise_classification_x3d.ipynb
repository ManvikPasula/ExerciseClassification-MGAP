# %% [markdown]
# **Introduction**
#
# This is a Google Colab Notebook which trains a X3D model (using pytorchvideo) on a dataset of videos. The dataset's directory should have 3 sub-directories, one for "train", "val", and "test". In each of these directories should be more directories, named with the dataset's classes. Then, within each of these directories should be videos, whose label corresponds to the directory they are placed in (e.g. dataset->train->archery->archery_1.mph).
#
# The "Set-up" section is used for downloading necessary packages and intiliazing variables. Take a look at the variables (such as file paths), and change them accordingly.
#
# The "Focal Loss and Dataset Distribution" section has code that finds distribution of the used dataset and uses the information to set up Focal Loss.
#
# The "Class Creation for Dataloaders" section creates the classes/objects necessary for creating and using dataloaders later in the process. Within this section is a commented code block which would change the transform function to one of a resnet. Uncommenting this code block, and changing the model to "make_resnet" in "Model Creation" would use a resnet50 instead.
#
# The "Model Creation" section creates the object that is used as the Lightning Module for the model.
#
# The "Training" section trains the model using the Trainer from Pytorch Lightning.
#
# The "Testing" section tests the model using Trainer.test.
#
# The "TSNE" section makes a TSNE.
#
# The "Testing 2" section uses a script that manually tests every file in the test dataset.

# %% [markdown]
# # Set-up

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %load_ext tensorboard

# %%
# !pip install pytorchvideo
# !pip install pytorch_lightning
# Out:
# Requirement already satisfied: pytorchvideo in /usr/local/lib/python3.10/dist-packages (0.1.5)
# Requirement already satisfied: fvcore in /usr/local/lib/python3.10/dist-packages (from pytorchvideo) (0.1.5.post20221221)
# Requirement already satisfied: av in /usr/local/lib/python3.10/dist-packages (from pytorchvideo) (11.0.0)
# Requirement already satisfied: parameterized in /usr/local/lib/python3.10/dist-packages (from pytorchvideo) (0.9.0)
# Requirement already satisfied: iopath in /usr/local/lib/python3.10/dist-packages (from pytorchvideo) (0.1.10)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from pytorchvideo) (3.2.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fvcore->pytorchvideo) (1.23.5)
# Requirement already satisfied: yacs>=0.1.6 in /usr/local/lib/python3.10/dist-packages (from fvcore->pytorchvideo) (0.1.8)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from fvcore->pytorchvideo) (6.0.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from fvcore->pytorchvideo) (4.66.1)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.10/dist-packages (from fvcore->pytorchvideo) (2.4.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from fvcore->pytorchvideo) (9.4.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from fvcore->pytorchvideo) (0.9.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from iopath->pytorchvideo) (4.5.0)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.10/dist-packages (from iopath->pytorchvideo) (2.8.2)
# Requirement already satisfied: pytorch_lightning in /usr/local/lib/python3.10/dist-packages (2.1.3)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (1.23.5)
# Requirement already satisfied: torch>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (2.1.0+cu121)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (4.66.1)
# Requirement already satisfied: PyYAML>=5.4 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (6.0.1)
# Requirement already satisfied: fsspec[http]>=2022.5.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (2023.6.0)
# Requirement already satisfied: torchmetrics>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (1.3.0.post0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (23.2)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (4.5.0)
# Requirement already satisfied: lightning-utilities>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (0.10.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2022.5.0->pytorch_lightning) (2.31.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2022.5.0->pytorch_lightning) (3.9.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.8.0->pytorch_lightning) (67.7.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.0->pytorch_lightning) (3.13.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.0->pytorch_lightning) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.0->pytorch_lightning) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.0->pytorch_lightning) (3.1.3)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.0->pytorch_lightning) (2.1.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (4.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.12.0->pytorch_lightning) (2.1.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>=2022.5.0->pytorch_lightning) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>=2022.5.0->pytorch_lightning) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>=2022.5.0->pytorch_lightning) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>=2022.5.0->pytorch_lightning) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.12.0->pytorch_lightning) (1.3.0)

# %%
import os
import pytorch_lightning
import pytorchvideo.data
import torch.utils.data
import torchvision
import pytorchvideo
import pytorchvideo.transforms
from torch.nn.functional import softmax
from typing import Dict
import json
import urllib
from torchvision.transforms import Compose, Lambda
from torchvision.transforms._transforms_video import (
    CenterCropVideo,
    NormalizeVideo,
)
from pytorchvideo.data.encoded_video import EncodedVideo
from pytorchvideo.transforms import (
    ApplyTransformToKey,
    ShortSideScale,
    UniformTemporalSubsample,
    UniformCropVideo
)
from pytorchvideo.transforms import (
    ApplyTransformToKey,
    Normalize,
    RandomShortSideScale,
    RemoveKey,
    ShortSideScale,
    UniformTemporalSubsample
)

from torchvision.transforms import (
    Compose,
    Lambda,
    RandomCrop,
    RandomHorizontalFlip
)
import sklearn
#from sklearn.metrics import accuracy_score
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/functional_tensor.py:5: UserWarning: The torchvision.transforms.functional_tensor module is deprecated in 0.15 and will be **removed in 0.17**. Please don't rely on it. You probably just need to use APIs in torchvision.transforms.functional or in torchvision.transforms.v2.functional.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/_functional_video.py:6: UserWarning: The 'torchvision.transforms._functional_video' module is deprecated since 0.12 and will be removed in the future. Please use the 'torchvision.transforms.functional' module instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/_transforms_video.py:22: UserWarning: The 'torchvision.transforms._transforms_video' module is deprecated since 0.12 and will be removed in the future. Please use the 'torchvision.transforms' module instead.
#   warnings.warn(

# %%
input_dir = '/content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1'
model_name = 'x3d_s'
checkpoint_path = '/content/drive/MyDrive/Research/Muscle Video/Checkpoints/x3d/' + model_name + '/pretrained'

num_classes=16
batch_size = 8
num_workers = 12
mean = [0.45, 0.45, 0.45]
std = [0.225, 0.225, 0.225]
model_transform_params  = {
    "x3d_xs": {
        "side_size": 182,
        "crop_size": 182,
        "num_frames": 4,
        "sampling_rate": 12,
    },
    "x3d_s": {
        "side_size": 182,
        "crop_size": 182,
        "num_frames": 13,
        "sampling_rate": 6,
    },
    "x3d_m": {
        "side_size": 256,
        "crop_size": 256,
        "num_frames": 16,
        "sampling_rate": 5,
    }
}
transform_params = model_transform_params[model_name]
frames_per_second = 30
slowfast_alpha = 4
clip_duration = (transform_params["num_frames"] * transform_params["sampling_rate"])/frames_per_second
device=('cuda' if torch.cuda.is_available() else 'cpu')
pretrained=False
learning_rate=0.0001
dropout_rate = 0.7
gamma = 2

# %%
import multiprocessing

cores = multiprocessing.cpu_count() # Count the number of cores in a computer
cores
# Out:
# 12

# %%
'''
pred_to_class = {
    0: "barbell biceps curl",
    1: "bench press",
    2: "chest fly machine",
    3: "deadlift",
    4: "decline bench press",
    5: "hammer curl",
    6: "hip thrust",
    7: "incline bench press",
    8: "lat pulldown",
    9: "lateral raise",
    10: "leg extension",
    11: "leg raises",
    12: "plank",
    13: "pull Up",
    14: "push-up",
    15: "romanian deadlift",
    16: "russian twist",
    17: "shoulder press",
    18: "squat",
    19: "t bar row",
    20: "tricep Pushdown",
    21: "tricep dips"
}
'''
pred_to_class = {
    0: "bench press",
    1: "bicep curl",
    2: "chest fly machine",
    3: "deadlift",
    4: "hip thrust",
    5: "lat pulling",
    6: "lateral raise",
    7: "leg extension",
    8: "leg raises",
    9: "push-up",
    10: "russian twist",
    11: "shoulder press",
    12: "squat",
    13: "t bar row",
    14: "tricep Pushdown",
    15: "tricep dips"
}

# %% [markdown]
# # Focal Loss and Dataset Distribution

# %%
dataset = input_dir

# %%
train_class_values = {}
test_class_values = {}
for split in os.listdir(dataset):
  new_path = os.path.join(dataset, split)
  for classname in os.listdir(new_path):
    class_path = os.path.join(new_path, classname)
    num_samples = len(os.listdir(class_path))
    print("In the", split, "split, for the", classname, "class, there are", num_samples, "samples.")
    if split=="train":
      train_class_values[classname] = num_samples
    if split=="test":
      test_class_values[classname] = num_samples
# Out:
# In the train split, for the bench press class, there are 183 samples.
# In the train split, for the lateral raise class, there are 67 samples.
# In the train split, for the chest fly machine class, there are 49 samples.
# In the train split, for the hip thrust class, there are 55 samples.
# In the train split, for the deadlift class, there are 129 samples.
# In the train split, for the leg extension class, there are 53 samples.
# In the train split, for the push-up class, there are 78 samples.
# In the train split, for the squat class, there are 77 samples.
# In the train split, for the leg raises class, there are 43 samples.
# In the train split, for the t bar row class, there are 60 samples.
# In the train split, for the shoulder press class, there are 42 samples.
# In the train split, for the russian twist class, there are 53 samples.
# In the train split, for the tricep Pushdown class, there are 40 samples.
# In the train split, for the tricep dips class, there are 72 samples.
# In the train split, for the bicep curl class, there are 106 samples.
# In the train split, for the lat pulling class, there are 111 samples.
# In the test split, for the bench press class, there are 37 samples.
# In the test split, for the lateral raise class, there are 33 samples.
# In the test split, for the chest fly machine class, there are 18 samples.
# In the test split, for the hip thrust class, there are 15 samples.
# In the test split, for the deadlift class, there are 49 samples.
# In the test split, for the leg extension class, there are 20 samples.
# In the test split, for the push-up class, there are 38 samples.
# In the test split, for the squat class, there are 39 samples.
# In the test split, for the leg raises class, there are 17 samples.
# In the test split, for the t bar row class, there are 28 samples.
# In the test split, for the shoulder press class, there are 23 samples.
# In the test split, for the russian twist class, there are 19 samples.
# In the test split, for the tricep Pushdown class, there are 17 samples.
# In the test split, for the tricep dips class, there are 25 samples.
# In the test split, for the bicep curl class, there are 30 samples.
# In the test split, for the lat pulling class, there are 34 samples.
# In the val split, for the bench press class, there are 37 samples.
# In the val split, for the lateral raise class, there are 33 samples.
# In the val split, for the chest fly machine class, there are 18 samples.
# In the val split, for the hip thrust class, there are 16 samples.
# In the val split, for the deadlift class, there are 49 samples.
# In the val split, for the leg extension class, there are 20 samples.
# In the val split, for the push-up class, there are 38 samples.
# In the val split, for the squat class, there are 39 samples.
# In the val split, for the leg raises class, there are 17 samples.
# In the val split, for the t bar row class, there are 28 samples.
# In the val split, for the shoulder press class, there are 23 samples.
# In the val split, for the russian twist class, there are 19 samples.
# In the val split, for the tricep Pushdown class, there are 17 samples.
# In the val split, for the tricep dips class, there are 25 samples.
# In the val split, for the bicep curl class, there are 30 samples.
# In the val split, for the lat pulling class, there are 34 samples.

# %%
train_class_values
# Out:
# {'bench press': 183,
#  'lateral raise': 67,
#  'chest fly machine': 49,
#  'hip thrust': 55,
#  'deadlift': 129,
#  'leg extension': 53,
#  'push-up': 78,
#  'squat': 77,
#  'leg raises': 43,
#  't bar row': 60,
#  'shoulder press': 42,
#  'russian twist': 53,
#  'tricep Pushdown': 40,
#  'tricep dips': 72,
#  'bicep curl': 106,
#  'lat pulling': 111}

# %%
test_class_values
# Out:
# {'bench press': 37,
#  'lateral raise': 33,
#  'chest fly machine': 18,
#  'hip thrust': 15,
#  'deadlift': 49,
#  'leg extension': 20,
#  'push-up': 38,
#  'squat': 39,
#  'leg raises': 17,
#  't bar row': 28,
#  'shoulder press': 23,
#  'russian twist': 19,
#  'tricep Pushdown': 17,
#  'tricep dips': 25,
#  'bicep curl': 30,
#  'lat pulling': 34}

# %%
total = 0
for classname in train_class_values:
  total = total + train_class_values[classname]

# %%
total
# Out:
# 1218

# %%
total_test = 0
for classname in test_class_values:
  total_test = total_test + test_class_values[classname]

# %%
total_test
# Out:
# 442

# %%
class_weights = {}
for classname in train_class_values:
  weight = 1 / (train_class_values[classname] / total)
  class_weights[classname] = weight

# %%
class_weights
# Out:
# {'bench press': 6.655737704918033,
#  'lateral raise': 18.17910447761194,
#  'chest fly machine': 24.857142857142858,
#  'hip thrust': 22.145454545454545,
#  'deadlift': 9.44186046511628,
#  'leg extension': 22.981132075471695,
#  'push-up': 15.615384615384615,
#  'squat': 15.818181818181817,
#  'leg raises': 28.325581395348838,
#  't bar row': 20.3,
#  'shoulder press': 29.0,
#  'russian twist': 22.981132075471695,
#  'tricep Pushdown': 30.45,
#  'tricep dips': 16.916666666666668,
#  'bicep curl': 11.490566037735848,
#  'lat pulling': 10.972972972972974}

# %%
class_to_int = {}
for i in pred_to_class:
  class_to_int[pred_to_class[i]]=i

# %%
class_to_int
# Out:
# {'bench press': 0,
#  'bicep curl': 1,
#  'chest fly machine': 2,
#  'deadlift': 3,
#  'hip thrust': 4,
#  'lat pulling': 5,
#  'lateral raise': 6,
#  'leg extension': 7,
#  'leg raises': 8,
#  'push-up': 9,
#  'russian twist': 10,
#  'shoulder press': 11,
#  'squat': 12,
#  't bar row': 13,
#  'tricep Pushdown': 14,
#  'tricep dips': 15}

# %%
list_weights = [None] * num_classes
for i in class_weights:
  list_weights[class_to_int[i]] = class_weights[i]
list_weights
# Out:
# [6.655737704918033,
#  11.490566037735848,
#  24.857142857142858,
#  9.44186046511628,
#  22.145454545454545,
#  10.972972972972974,
#  18.17910447761194,
#  22.981132075471695,
#  28.325581395348838,
#  15.615384615384615,
#  22.981132075471695,
#  29.0,
#  15.818181818181817,
#  20.3,
#  30.45,
#  16.916666666666668]

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
from torchvision.ops.focal_loss import sigmoid_focal_loss

# %%
#focal_loss = sigmoid_focal_loss(alpha=class_weights, gamma=2)

# %% [markdown]
# # Class Creation for Dataloaders

# %%
import pytorchvideo.models.x3d

def post_act(input):
  return softmax(input, dim=1)

'''
def make_x3d():
    return pytorchvideo.models.x3d.create_x3d(
        input_channel=3,
        input_clip_length=clip_duration,
        input_crop_size=transform_params["crop_size"],
        model_num_class=num_classes,
        norm=nn.BatchNorm3d,
        activation=nn.ReLU,
        dropout_rate=dropout_rate,
    )
'''

transform =  ApplyTransformToKey(
    key="video",
    transform=Compose(
        [
            UniformTemporalSubsample(transform_params["num_frames"]),
            Lambda(lambda x: x/255.0),
            NormalizeVideo(mean, std),
            ShortSideScale(size=transform_params["side_size"]),
            CenterCropVideo(
                crop_size=(transform_params["crop_size"], transform_params["crop_size"])
            )
        ]
    ),
)

# %%
class VideosDataModule(pytorch_lightning.LightningDataModule):

    # Dataset configuration
    _DATA_PATH = input_dir
    _CLIP_DURATION = clip_duration  # Duration of sampled clip for each video
    _BATCH_SIZE = batch_size
    _NUM_WORKERS = num_workers  # Number of parallel processes fetching data

    def train_dataloader(self):
        #Create the train partition from the list of video labels and video paths
        train_dataset = pytorchvideo.data.labeled_video_dataset(
            data_path=os.path.join(self._DATA_PATH, 'train'),
            clip_sampler=pytorchvideo.data.make_clip_sampler("random", self._CLIP_DURATION),
            decode_audio=False,
            transform=transform
        )

        return torch.utils.data.DataLoader(
            train_dataset,
            batch_size=self._BATCH_SIZE,
            num_workers=self._NUM_WORKERS
        )

    def val_dataloader(self):
        #Create the validation partition from the list of video labels and video paths
        val_dataset = pytorchvideo.data.labeled_video_dataset(
            data_path=os.path.join(self._DATA_PATH, 'val'),
            clip_sampler=pytorchvideo.data.make_clip_sampler("random", self._CLIP_DURATION),
            decode_audio=False,
            transform=transform
        )

        return torch.utils.data.DataLoader(
            val_dataset,
            batch_size=self._BATCH_SIZE,
            num_workers=self._NUM_WORKERS,
        )

    def test_dataloader(self):
        test_dataset = pytorchvideo.data.labeled_video_dataset(
            data_path=os.path.join(self._DATA_PATH, 'test'),
            clip_sampler=pytorchvideo.data.make_clip_sampler("random", self._CLIP_DURATION),
            decode_audio=False,
            transform=transform
        )

        return torch.utils.data.DataLoader(
            test_dataset,
            batch_size=self._BATCH_SIZE,
            num_workers=self._NUM_WORKERS,
        )

# %% [markdown]
# # Model Creation

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
from torchmetrics.classification import MulticlassAccuracy
from torch.nn import Linear
from sklearn.metrics import roc_auc_score
from sklearn.metrics import precision_recall_fscore_support
import numpy as np

mca1 = MulticlassAccuracy(num_classes=num_classes, average='micro', top_k=1)
mca5 = MulticlassAccuracy(num_classes=num_classes, average='micro', top_k=5)

class VideoClassificationLightningModule(pytorch_lightning.LightningModule):

    def __init__(self):
        super().__init__()

        self.model = torch.hub.load('facebookresearch/pytorchvideo', model_name, pretrained=True)
        self.model.to(device)
        self.model.blocks[5].proj = Linear(in_features=2048, out_features=num_classes, bias=True)
        self.model.train()

    def forward(self, x):
        return self.model(x)

    def training_step(self, batch, batch_idx):
        # The model expects a video tensor of shape (B, C, T, H, W), which is the
        # format provided by the dataset
        y_hat = self.model(batch["video"])

        # Compute cross entropy loss, loss.backwards will be called behind the scenes
        # by PyTorchLightning after being returned from this method.

        loss = F.cross_entropy(y_hat, batch["label"])

        # Log the train loss to Tensorboard
        self.log("train_loss", loss.item(), batch_size=batch_size)

        acc1 = mca1(y_hat.cpu(), batch["label"].cpu())
        acc5 = mca5(y_hat.cpu(), batch["label"].cpu())
        self.log("train_accuracy_top_1", acc1.item(), batch_size=batch_size)
        self.log("train_accuracy_top_5", acc5.item(), batch_size=batch_size)

        print("train_loss:", loss.item(), "train_accuracy_top_1:", acc1.item(), "train_accuracy_top_5:", acc5.item())

        return loss

    def validation_step(self, batch, batch_idx):
        y_hat = self.model(batch["video"])
        loss = F.cross_entropy(y_hat, batch["label"])

        self.log("val_loss", loss.item(), batch_size=batch_size)

        acc1 = mca1(y_hat.cpu(), batch["label"].cpu())
        acc5 = mca5(y_hat.cpu(), batch["label"].cpu())
        self.log("val_accuracy_top_1", acc1.item(), batch_size=batch_size)
        self.log("val_accuracy_top_5", acc5.item(), batch_size=batch_size)

        print("val_loss:", loss.item(), "val_accuracy_top_1:", acc1.item(), "val_accuracy_top_5:", acc5.item())

        return loss

    def configure_optimizers(self):
        """
        Setup the Adam optimizer. Note, that this function also can return a lr scheduler, which is
        usually useful for training video models.
        """
        return torch.optim.Adam(self.parameters(), lr=learning_rate)

    def test_step(self, batch, batch_idx):
        y_hat = self.model(batch["video"])
        loss = F.cross_entropy(y_hat, batch["label"])

        # logs metrics for each testing_step,
        # and the average across the epoch, to the progress bar and logger
        self.log("test_loss", loss.item(), batch_size=batch_size)

        acc1 = mca1(y_hat.cpu(), batch["label"].cpu())
        acc5 = mca5(y_hat.cpu(), batch["label"].cpu())
        self.log("test_accuracy_top_1", acc1.item(), batch_size=batch_size)
        self.log("test_accuracy_top_5", acc5.item(), batch_size=batch_size)

        softed = post_act(y_hat)
        auc = roc_auc_score(y_true=batch["label"].cpu(), y_score=softed.cpu(), multi_class='ovr', average='micro', labels=np.arange(num_classes))
        self.log("auc", auc, batch_size=batch_size)

        pred_classes = []
        for x in softed:
          class_index = x.topk(k=1).indices
          class_index = class_index[0]
          pred_classes.append(class_index)
        pred_classes = torch.Tensor(pred_classes)

        rpf1 = precision_recall_fscore_support(y_true=batch["label"].cpu(), y_pred=pred_classes.cpu(), beta=1, labels=np.arange(num_classes), average='macro', zero_division=1)
        precision = rpf1[0]
        recall = rpf1[1]
        f1 = rpf1[2]
        self.log("precision", precision, batch_size=batch_size)
        self.log("recall", recall, batch_size=batch_size)
        self.log("f1", f1, batch_size=batch_size)

        print("test_loss:", loss.item(), "test_accuracy_top_1:", acc1.item(), "test_accuracy_top_5:", acc5.item(), "auc:", auc, "precision:", precision, "recall:", recall, "f1:", f1)

        return loss

# %% [markdown]
# # Training

# %%
from pytorch_lightning.callbacks import EarlyStopping

early_stopping_callbacks = EarlyStopping(monitor="val_loss", min_delta=0, patience=30, verbose=True, mode="min")

# %%
classification_module = VideoClassificationLightningModule()
data_module = VideosDataModule()
trainer = pytorch_lightning.Trainer(
    default_root_dir=checkpoint_path,
    max_epochs=30,
    accelerator="auto",
    devices="auto",
    strategy='auto',
    enable_checkpointing=True,
    logger=True,
)
#    callbacks=[early_stopping_callbacks],
# Out:
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs

# %%
torch.set_float32_matmul_precision('medium')

# %%
trainer.fit(classification_module, data_module, ckpt_path='/content/drive/MyDrive/Research/Muscle Video/Checkpoints/x3d/x3d_s/not pretrained/lightning_logs/version_0/checkpoints/epoch=7-step=1024.ckpt')
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:Restoring states from the checkpoint path at /content/drive/MyDrive/Research/Muscle Video/Checkpoints/x3d/x3d_s/not pretrained/lightning_logs/version_0/checkpoints/epoch=7-step=1024.ckpt
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/callbacks/model_checkpoint.py:347: The dirpath has changed from '/content/drive/MyDrive/Research/Muscle Video/Checkpoints/x3d/x3d_s/not pretrained/lightning_logs/version_0/checkpoints' to '/content/drive/MyDrive/Research/Muscle Video/Checkpoints/x3d/x3d_s/not pretrained/lightning_logs/version_1/checkpoints', therefore `best_model_score`, `kth_best_model_path`, `kth_value`, `last_model_path` and `best_k_models` won't be reloaded. Only `best_model_path` will be reloaded.
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name  | Type | Params
# -------------------------------
# 0 | model | Net  | 3.0 M
# -------------------------------
# 3.0 M     Trainable params
# 0         Non-trainable params
# 3.0 M     Total params
# 12.030    Total estimated model params size (MB)
# INFO:pytorch_lightning.utilities.rank_zero:Restored all states from the checkpoint at /content/drive/MyDrive/Research/Muscle Video/Checkpoints/x3d/x3d_s/not pretrained/lightning_logs/version_0/checkpoints/epoch=7-step=1024.ckpt
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
val_accuracy_top_1: 0.25 val_accuracy_top_5: 0.375
# val_loss: 2.4573752880096436 val_accuracy_top_1: 0.375 val_accuracy_top_5: 0.875
# val_loss: 2.7280988693237305 val_accuracy_top_1: 0.125 val_accuracy_top_5: 0.25
# val_loss: 2.6064701080322266 val_accuracy_top_1: 0.25 val_accuracy_top_5: 0.375
# val_loss: 2.2462892532348633 val_accuracy_top_1: 0.625 val_accuracy_top_5: 0.75
# val_loss: 2.6300344467163086 val_accuracy_top_1: 0.25 val_accuracy_top_5: 0.25
# val_loss: 2.7285361289978027 val_accuracy_top_1: 0.125 val_accuracy_top_5: 0.25
# val_loss: 2.67240047454834 val_accuracy_top_1: 0.25 val_accuracy_top_5: 0.25
# val_loss: 2.6193642616271973 val_accuracy_top_1: 0.25 val_accuracy_top_5: 0.375
# val_loss: 2.5231869220733643 val_accuracy_top_1: 0.375 val_accuracy_top_5: 0.75
# val_loss: 2.244155168533325 val_accuracy_top_1: 0.625 val_accuracy_top_5: 0.75
# val_loss: 2.2921135425567627 val_accuracy_top_1: 0.625 val_accuracy_top_5: 0.75
# val_loss: 2.370323896408081 val_accuracy_top_1: 0.5 val_accuracy_top_5: 0.625
# val_loss: 2.7775063514709473 val_accuracy_top_1: 0.125 val_accuracy_top_5: 0.5
# val_loss: 2.4316790103912354 val_accuracy_top_1: 0.5 val_accuracy_top_5: 0.75
# val_loss: 2.4755380153656006 val_accuracy_top_1: 0.375 val_accuracy_top_5: 0.625
# val_loss: 2.370387315750122 val_accuracy_top_1: 0.5 val_accuracy_top_5: 0.75
# val_loss: 2.4806230068206787 val_accuracy_top_1: 0.375 val_accuracy_top_5: 0.5
# val_loss: 2.3687291145324707 val_accuracy_top_1: 0.5 val_accuracy_top_5: 0.5
# val_loss: 2.1679277420043945 val_accuracy_top_1: 0.75 val_accuracy_top_5: 0.875
# val_loss: 2.500432252883911 val_accuracy_top_1: 0.375 val_accuracy_top_5: 0.625
# val_loss: 2.824592113494873 val_accuracy_top_1: 0.0 val_accuracy_top_5: 0.75
# val_loss: 2.6161575317382812 val_accuracy_top_1: 0.25 val_accuracy_top_5: 0.25
# val_loss: 2.7358193397521973 val_accuracy_top_1: 0.125 val_accuracy_top_5: 0.375
# val_loss: 2.5537500381469727 val_accuracy_top_1: 0.25 val_accuracy_top_5: 0.5
# val_loss: 2.5220067501068115 val_accuracy_top_1: 0.375 val_accuracy_top_5: 0.625
# val_loss: 2.8084170818328857 val_accuracy_top_1: 0.0 val_accuracy_top_5: 0.375
# val_loss: 2.7373170852661133 val_accuracy_top_1: 0.125 val_accuracy_top_5: 0.125
# val_loss: 2.575195789337158 val_accuracy_top_1: 0.375 val_accuracy_top_5: 0.375
# val_loss: 2.250645160675049 val_accuracy_top_1: 0.75 val_accuracy_top_5: 0.75
# val_loss: 2.5719940662384033 val_accuracy_top_1: 0.25 val_accuracy_top_5: 0.625
# val_loss: 2.2452471256256104 val_accuracy_top_1: 0.625 val_accuracy_top_5: 0.625
# val_loss: 2.3508405685424805 val_accuracy_top_1: 0.625 val_accuracy_top_5: 0.875
# val_loss: 2.50046968460083 val_accuracy_top_1: 0.375 val_accuracy_top_5: 0.875
# val_loss: 2.608370065689087 val_accuracy_top_1: 0.25 val_accuracy_top_5: 0.5
# val_loss: 2.854285955429077 val_accuracy_top_1: 0.0 val_accuracy_top_5: 1.0
# val_loss: 2.8742239475250244 val_accuracy_top_1: 0.0 val_accuracy_top_5: 0.0
# val_loss: 1.874740719795227 val_accuracy_top_1: 1.0 val_accuracy_top_5: 1.0
# val_loss: 2.82688307762146 val_accuracy_top_1: 0.0 val_accuracy_top_5: 1.0
# val_loss: 2.874519109725952 val_accuracy_top_1: 0.0 val_accuracy_top_5: 1.0
# val_loss: 2.0532431602478027 val_accuracy_top_1: 1.0 val_accuracy_top_5: 1.0
# val_loss: 2.848696708679199 val_accuracy_top_1: 0.0 val_accuracy_top_5: 0.0
# val_loss: 2.8682918548583984 val_accuracy_top_1: 0.0 val_accuracy_top_5: 0.0
# val_loss: 2.8517191410064697 val_accuracy_top_1: 0.0 val_accuracy_top_5: 0.0
# val_loss: 2.866307020187378 val_accuracy_top_1: 0.0 val_accuracy_top_5: 0.0
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=30` reached.

# %% [markdown]
# # Testing

# %%
best_checkpoint_path = '/content/drive/MyDrive/Research/Muscle Video/Checkpoints/x3d/x3d_s/lightning_logs/version_5/checkpoints/epoch=29-step=3840.ckpt'

# %%
trainer.test(model=classification_module, datamodule=data_module, ckpt_path=best_checkpoint_path, verbose=True)
# Out:
# WARNING:pytorch_lightning.loggers.tensorboard:Missing logger folder: /content/drive/MyDrive/Research/Muscle Video/Checkpoints/x3d/x3d_s/pretrained/lightning_logs
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/call.py:54: Detected KeyboardInterrupt, attempting graceful shutdown...

# %% [markdown]
# # TSNE

# %%
TSNE_model = VideoClassificationLightningModule.load_from_checkpoint(best_checkpoint_path)
TSNE_model.to('cpu')
TSNE_model.model.blocks.pop(5)
TSNE_model.eval()
print("done")
# Out:
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# done

# %%
from sklearn.manifold import TSNE
import random
import matplotlib.pyplot as plt

# %%
seed = 10
random.seed(seed)
torch.manual_seed(seed)
np.random.seed(seed)

# %%
labels = []
features = None

# %%
thingy = data_module.test_dataloader()
for batch in thingy:
  x = batch["video"]
  labels += batch["label"]

  with torch.no_grad():
    output = TSNE_model(x)
    output = torch.flatten(output, 1)

  current_features = output.cpu().numpy()

  if features is not None:
    features = np.concatenate((features, current_features))
  else:
    features = current_features

# %%
tsne = TSNE(n_components=2).fit_transform(features)

# %%
# scale and move the coordinates so they fit [0; 1] range
def scale_to_01_range(x):
    # compute the distribution range
    value_range = (np.max(x) - np.min(x))

    # move the distribution so that it starts from zero
    # by extracting the minimal value from all its values
    starts_from_zero = x - np.min(x)

    # make the distribution fit [0; 1] by dividing by its range
    return starts_from_zero / value_range

# extract x and y coordinates representing the positions of the images on T-SNE plot
tx = tsne[:, 0]
ty = tsne[:, 1]

tx = scale_to_01_range(tx)
ty = scale_to_01_range(ty)

# %%
colors_per_class = {
    0: [254, 202, 87],
    1: [255, 107, 107],
    2: [10, 189, 227],
    3: [255, 159, 243],
    4: [16, 172, 132],
    5: [128, 80, 128],
    6: [87, 101, 116],
    7: [52, 31, 151],
    8: [0, 0, 0],
    9: [100, 100, 255],
    10: [128, 109, 84],
    11: [15, 245, 218],
    12: [242, 10, 21],
    13: [242, 10, 149],
    14: [40, 242, 0],
    15: [255, 153, 10]
}

# %%
# initialize a matplotlib plot
fig = plt.figure()
ax = fig.add_subplot(111)

# for every class, we'll add a scatter plot separately
for label in colors_per_class:
    # find the samples of the current class in the data
    indices = [i for i, l in enumerate(labels) if l == label]

    # extract the coordinates of the points of this class only
    current_tx = np.take(tx, indices)
    current_ty = np.take(ty, indices)

    # convert the class color to matplotlib format
    color = np.array(colors_per_class[label], dtype=np.float) / 255

    # add a scatter plot with the corresponding color and label
    ax.scatter(current_tx, current_ty, c=color, label=label, s=15)

# build a legend using the labels we set previously
ax.legend(loc='best')

# finally, show the plot
plt.show()
# Out:
# <ipython-input-58-885392fecd81>:15: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   color = np.array(colors_per_class[label], dtype=np.float) / 255
# <ipython-input-58-885392fecd81>:18: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   ax.scatter(current_tx, current_ty, c=color, label=label, s=15)

# %% [markdown]
# # Testing 2

# %%
prediction_model = classification_module.load_from_checkpoint(best_checkpoint_path)
prediction_model.to(device)
prediction_model.freeze()

# %%
testing_dir = os.path.join(input_dir, "test")
numSeen = 0
numCorrectTop1 = 0
numCorrectTop5 = 0
classWiseTop1 = {}
classWiseTop5 = {}

for i in pred_to_class:
  classWiseTop1[pred_to_class[i]] = 0
  classWiseTop5[pred_to_class[i]] = 0

for folder in os.listdir(testing_dir):
  new_path = os.path.join(testing_dir, folder)
  for file_name in os.listdir(new_path):
    video_path = os.path.join(new_path, file_name)

    start_sec = 0
    end_sec = start_sec + clip_duration

    video = EncodedVideo.from_path(video_path)

    video_data = video.get_clip(start_sec=start_sec, end_sec=end_sec)

    video_data = transform(video_data)

    inputs = video_data["video"]
    inputs = [i.to(device)[None, ...] for i in inputs]

    preds = prediction_model(inputs)

    preds = post_act(preds)
    pred_classes = preds.topk(k=5).indices

    pred_class_names = [pred_to_class[int(i)] for i in pred_classes[0]]

    numSeen += 1

    if pred_class_names[0] == folder:
        numCorrectTop1 += 1
        classWiseTop1[folder] += 1

    if folder in pred_class_names:
        numCorrectTop5 += 1
        classWiseTop5[folder] += 1

    print("Current Top1:", (numCorrectTop1 / numSeen) * 100, "%")
    print(video_path)
    print(folder)
    print(pred_class_names)

print("Evaluation Finished")
top1accuracy = (numCorrectTop1 / numSeen) * 100
top5accuracy = (numCorrectTop5 / numSeen) * 100
print("Top 1 Accuracy:", top1accuracy, "%")
print("Top 5 Accuracy:", top5accuracy, "%")

classWiseTop1_accuracy = {}
classWiseTop5_accuracy = {}
for i in classWiseTop1:
  classWiseTop1_accuracy[i] = (classWiseTop1[i] / test_class_values[i]) * 100
  classWiseTop5_accuracy[i] = (classWiseTop5[i] / test_class_values[i]) * 100

print(classWiseTop1_accuracy)
print(classWiseTop5_accuracy)
# Out:
# Current Top1: 0.0 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/bench press/bench press_57_0.mp4
# bench press
# ['tricep Pushdown', 'chest fly machine', 'bench press', 'shoulder press', 'leg raises']
# Current Top1: 0.0 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/bench press/bench press_57_1.mp4
# bench press
# ['tricep Pushdown', 'chest fly machine', 'bench press', 'shoulder press', 'russian twist']
# Current Top1: 33.33333333333333 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/bench press/bench press_18_0.mp4
# bench press
# ['bench press', 'tricep Pushdown', 'shoulder press', 'chest fly machine', 'lat pulling']
# Current Top1: 25.0 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/bench press/bench press_30_0.mp4
# bench press
# ['chest fly machine', 'bench press', 'tricep Pushdown', 'shoulder press', 'deadlift']
# Current Top1: 40.0 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/bench press/bench press_26_0.mp4
# bench press
# ['bench press', 'chest fly machine', 'tricep Pushdown', 'shoulder press', 'leg extension']
# Current Top1: 33.33333333333333 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/bench press/bench press_17_0.mp4
# bench press
# ['chest fly machine', 'deadlift', 'push-up', 'lateral raise', 'bicep curl']
# Current Top1: 28.57142857142857 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/bench press/bench press_23_0.mp4
# bench press
# ['chest fly machine', 'bench press', 'shoulder press', 'leg extension', 'tricep Pushdown']
# Current Top1: 25.0 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/bench press/bench press_49_0.mp4
# bench press
# ['bicep curl', 'squat', 'shoulder press', 'bench press', 'tricep Pushdown']
# Current Top1: 33.33333333333333 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/bench press/bench press_15_0.mp4
# bench press
# ['bench press', 'chest fly machine', 'hip thrust', 'tricep Pushdown', 'bicep curl']
# Current Top1: 30.0 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/bench press/bench press_51_0.mp4
# bench press
# ['shoulder press', 'leg raises', 'tricep Pushdown', 'chest fly machine', 'bicep curl']
# Current Top1: 36.36363636363637 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/bench press/bench press_48_0.mp4
# bench press
# ['bench press', 'chest fly machine', 'shoulder press', 'hip thrust', 'leg extension']
# Current Top1: 41.66666666666667 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/bench press/bench press_48_1.mp4
# bench press
# ['bench press', 'chest fly machine', 'shoulder press', 'hip thrust', 'leg extension']
# Current Top1: 46.15384615384615 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/bench press/bench press_48_2.mp4
# bench press
# ['bench press', 'chest fly machine', 'shoulder press', 'hip thrust', 'leg extension']
# Current Top1: 42.857142857142854 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/bench press/incline bench press_17_0.mp4
# bench press
# ['chest fly machine', 't bar row', 'lat pulling', 'shoulder press', 'bench press']
# Current Top1: 40.0 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/bench press/incline bench press_19_0.mp4
# bench press
# ['tricep dips', 'lat pulling', 'shoulder press', 'hip thrust', 'tricep Pushdown']
# Current Top1: 43.75 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/bench press/incline bench press_25_0.mp4
# bench press
# ['bench press', 'hip thrust', 'lat pulling', 'deadlift', 'lateral raise']
# Current Top1: 41.17647058823529 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/bench press/incline bench press_10_0.mp4
# bench press
# ['russian twist', 'tricep Pushdown', 'bench press', 'chest fly machine', 'shoulder press']
# Current Top1: 38.88888888888889 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/bench press/incline bench press_22_0.mp4
# bench press
# ['chest fly machine', 'hip thrust', 'shoulder press', 'bench press', 'leg raises']
# Current Top1: 36.84210526315789 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/bench press/dbp_4_0.MOV
# bench press
# ['tricep Pushdown', 'squat', 'hip thrust', 'bench press', 'chest fly machine']
# Current Top1: 35.0 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/bench press/dbp_4_1.MOV
# bench press
# ['tricep Pushdown', 'bench press', 'hip thrust', 'squat', 'chest fly machine']
# Current Top1: 38.095238095238095 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/bench press/dbp_4_2.MOV
# bench press
# ['bench press', 'tricep Pushdown', 'hip thrust', 'chest fly machine', 'shoulder press']
# Current Top1: 40.909090909090914 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/bench press/dbp_4_3.MOV
# bench press
# ['bench press', 'tricep Pushdown', 'chest fly machine', 'deadlift', 'hip thrust']
# Current Top1: 43.47826086956522 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/bench press/dbp_4_4.MOV
# bench press
# ['bench press', 'tricep Pushdown', 'chest fly machine', 'hip thrust', 'deadlift']
# Current Top1: 41.66666666666667 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/bench press/dbp_4_5.MOV
# bench press
# ['tricep Pushdown', 'bench press', 'chest fly machine', 'deadlift', 'hip thrust']
# Current Top1: 44.0 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/bench press/dbp_4_6.MOV
# bench press
# ['bench press', 'tricep Pushdown', 'chest fly machine', 'deadlift', 'hip thrust']
# Current Top1: 46.15384615384615 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/bench press/dbp_4_7.MOV
# bench press
# ['bench press', 'deadlift', 'tricep Pushdown', 'chest fly machine', 'hip thrust']
# Current Top1: 44.44444444444444 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/bench press/dbp_4_8.MOV
# bench press
# ['tricep Pushdown', 'bench press', 'chest fly machine', 'hip thrust', 'deadlift']
# Current Top1: 46.42857142857143 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/bench press/dbp_4_9.MOV
# bench press
# ['bench press', 'tricep Pushdown', 'hip thrust', 'chest fly machine', 'deadlift']
# Current Top1: 48.275862068965516 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/bench press/dbp_4_10.MOV
# bench press
# ['bench press', 'tricep Pushdown', 'chest fly machine', 'hip thrust', 'deadlift']
# Current Top1: 46.666666666666664 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/bench press/dbp_3_0.MOV
# bench press
# ['lat pulling', 'push-up', 'tricep dips', 'squat', 'shoulder press']
# Current Top1: 45.16129032258064 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/bench press/dbp_3_1.MOV
# bench press
# ['shoulder press', 'tricep Pushdown', 'squat', 'deadlift', 'tricep dips']
# Current Top1: 43.75 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/bench press/dbp_3_2.MOV
# bench press
# ['shoulder press', 'squat', 'tricep Pushdown', 'leg extension', 'tricep dips']
# Current Top1: 45.45454545454545 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/bench press/dbp_10_0.mp4
# bench press
# ['bench press', 'hip thrust', 'lat pulling', 'squat', 'tricep dips']
# Current Top1: 47.05882352941176 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/bench press/dbp_10_1.mp4
# bench press
# ['bench press', 'hip thrust', 'lat pulling', 'squat', 'lateral raise']
# Current Top1: 48.57142857142857 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/bench press/dbp_10_2.mp4
# bench press
# ['bench press', 'hip thrust', 'lat pulling', 'squat', 'tricep Pushdown']
# Current Top1: 50.0 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/bench press/dbp_10_3.mp4
# bench press
# ['bench press', 'hip thrust', 'squat', 'lat pulling', 'tricep dips']
# Current Top1: 51.35135135135135 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/bench press/dbp_10_4.mp4
# bench press
# ['bench press', 'hip thrust', 'squat', 'lat pulling', 'tricep dips']
# Current Top1: 52.63157894736842 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lateral raise/lateral raise_13_0.mp4
# lateral raise
# ['lateral raise', 'hip thrust', 'bicep curl', 'lat pulling', 't bar row']
# Current Top1: 53.84615384615385 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lateral raise/lateral raise_13_1.mp4
# lateral raise
# ['lateral raise', 'hip thrust', 'lat pulling', 'tricep dips', 'bicep curl']
# Current Top1: 52.5 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lateral raise/lateral raise_37_0.mp4
# lateral raise
# ['tricep Pushdown', 'deadlift', 'lateral raise', 'squat', 'shoulder press']
# Current Top1: 51.21951219512195 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lateral raise/lateral raise_37_1.mp4
# lateral raise
# ['tricep Pushdown', 'squat', 'lateral raise', 'deadlift', 'chest fly machine']
# Current Top1: 50.0 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lateral raise/lateral raise_37_2.mp4
# lateral raise
# ['tricep Pushdown', 'squat', 'shoulder press', 'chest fly machine', 'lateral raise']
# Current Top1: 48.837209302325576 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lateral raise/lateral raise_37_3.mp4
# lateral raise
# ['tricep Pushdown', 'squat', 'lateral raise', 'deadlift', 'shoulder press']
# Current Top1: 47.72727272727273 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lateral raise/lateral raise_37_4.mp4
# lateral raise
# ['tricep Pushdown', 'squat', 'lateral raise', 'deadlift', 'shoulder press']
# Current Top1: 48.888888888888886 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lateral raise/lateral raise_15_0.mp4
# lateral raise
# ['lateral raise', 'lat pulling', 'hip thrust', 'bicep curl', 'deadlift']
# Current Top1: 47.82608695652174 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lateral raise/lateral raise_6_0.MOV
# lateral raise
# ['leg raises', 'squat', 'shoulder press', 'hip thrust', 'lat pulling']
# Current Top1: 46.808510638297875 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lateral raise/lateral raise_6_1.MOV
# lateral raise
# ['leg raises', 'squat', 'hip thrust', 'shoulder press', 'chest fly machine']
# Current Top1: 45.83333333333333 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lateral raise/lateral raise_6_2.MOV
# lateral raise
# ['leg raises', 'shoulder press', 'hip thrust', 'squat', 'russian twist']
# Current Top1: 44.89795918367347 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lateral raise/lateral raise_6_3.MOV
# lateral raise
# ['leg raises', 'russian twist', 'hip thrust', 'squat', 'shoulder press']
# Current Top1: 44.0 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lateral raise/lateral raise_6_4.MOV
# lateral raise
# ['leg raises', 'hip thrust', 'squat', 'shoulder press', 'russian twist']
# Current Top1: 43.13725490196079 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lateral raise/lateral raise_6_5.MOV
# lateral raise
# ['leg raises', 'russian twist', 'hip thrust', 'squat', 'shoulder press']
# Current Top1: 42.30769230769231 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lateral raise/lateral raise_6_6.MOV
# lateral raise
# ['leg raises', 'russian twist', 'hip thrust', 'squat', 'shoulder press']
# Current Top1: 41.509433962264154 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lateral raise/lateral raise_6_7.MOV
# lateral raise
# ['russian twist', 'leg raises', 'hip thrust', 'squat', 'shoulder press']
# Current Top1: 40.74074074074074 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lateral raise/lateral raise_6_8.MOV
# lateral raise
# ['leg raises', 'russian twist', 'hip thrust', 'shoulder press', 'squat']
# Current Top1: 41.81818181818181 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lateral raise/lateral raise_31_0.mp4
# lateral raise
# ['lateral raise', 'tricep Pushdown', 'hip thrust', 'squat', 'shoulder press']
# Current Top1: 42.857142857142854 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lateral raise/lateral raise_31_1.mp4
# lateral raise
# ['lateral raise', 'hip thrust', 'shoulder press', 'squat', 'tricep Pushdown']
# Current Top1: 43.859649122807014 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lateral raise/lateral raise_31_2.mp4
# lateral raise
# ['lateral raise', 'hip thrust', 'tricep Pushdown', 'squat', 'lat pulling']
# Current Top1: 44.827586206896555 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lateral raise/lateral raise_31_3.mp4
# lateral raise
# ['lateral raise', 'tricep Pushdown', 'squat', 'hip thrust', 'shoulder press']
# Current Top1: 45.76271186440678 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lateral raise/lateral raise_17_0.mp4
# lateral raise
# ['lateral raise', 'bicep curl', 'hip thrust', 'bench press', 'deadlift']
# Current Top1: 46.666666666666664 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lateral raise/lateral raise_17_1.mp4
# lateral raise
# ['lateral raise', 'bicep curl', 'hip thrust', 'squat', 'bench press']
# Current Top1: 47.540983606557376 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lateral raise/lateral raise_17_2.mp4
# lateral raise
# ['lateral raise', 'bicep curl', 'bench press', 'deadlift', 'hip thrust']
# Current Top1: 46.774193548387096 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lateral raise/lateral raise_3_0.MOV
# lateral raise
# ['leg raises', 'hip thrust', 'russian twist', 'squat', 'lateral raise']
# Current Top1: 46.03174603174603 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lateral raise/lateral raise_3_1.MOV
# lateral raise
# ['leg raises', 'hip thrust', 'lat pulling', 'shoulder press', 'russian twist']
# Current Top1: 45.3125 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lateral raise/lateral raise_3_2.MOV
# lateral raise
# ['leg raises', 'russian twist', 'hip thrust', 'squat', 'lat pulling']
# Current Top1: 44.61538461538462 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lateral raise/lateral raise_3_3.MOV
# lateral raise
# ['leg raises', 'russian twist', 'hip thrust', 'squat', 'lateral raise']
# Current Top1: 43.93939393939394 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lateral raise/lateral raise_3_4.MOV
# lateral raise
# ['russian twist', 'leg raises', 'hip thrust', 'squat', 'lateral raise']
# Current Top1: 43.28358208955223 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lateral raise/lateral raise_3_5.MOV
# lateral raise
# ['russian twist', 'leg raises', 'hip thrust', 'squat', 'lateral raise']
# Current Top1: 42.64705882352941 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lateral raise/lateral raise_3_6.MOV
# lateral raise
# ['leg raises', 'russian twist', 'hip thrust', 'squat', 'lateral raise']
# Current Top1: 43.47826086956522 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lateral raise/lateral raise_12_0.mp4
# lateral raise
# ['lateral raise', 'hip thrust', 'bicep curl', 'lat pulling', 'squat']
# Current Top1: 44.285714285714285 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lateral raise/lateral raise_12_1.mp4
# lateral raise
# ['lateral raise', 'hip thrust', 'lat pulling', 'bicep curl', 'bench press']
# Current Top1: 45.07042253521127 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/chest fly machine/chest fly machine_22_0.mp4
# chest fly machine
# ['chest fly machine', 'leg extension', 'tricep Pushdown', 'deadlift', 'shoulder press']
# Current Top1: 45.83333333333333 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/chest fly machine/chest fly machine_22_1.mp4
# chest fly machine
# ['chest fly machine', 'leg extension', 'tricep Pushdown', 'deadlift', 'shoulder press']
# Current Top1: 46.57534246575342 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/chest fly machine/chest fly machine_22_2.mp4
# chest fly machine
# ['chest fly machine', 'leg extension', 'tricep Pushdown', 'deadlift', 'shoulder press']
# Current Top1: 47.2972972972973 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/chest fly machine/chest fly machine_22_3.mp4
# chest fly machine
# ['chest fly machine', 'leg extension', 'deadlift', 'tricep Pushdown', 'shoulder press']
# Current Top1: 48.0 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/chest fly machine/chest fly machine_22_4.mp4
# chest fly machine
# ['chest fly machine', 'leg extension', 'deadlift', 'tricep Pushdown', 'shoulder press']
# Current Top1: 48.68421052631579 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/chest fly machine/chest fly machine_22_5.mp4
# chest fly machine
# ['chest fly machine', 'leg extension', 'tricep Pushdown', 'deadlift', 'shoulder press']
# Current Top1: 49.35064935064935 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/chest fly machine/chest fly machine_22_6.mp4
# chest fly machine
# ['chest fly machine', 'leg extension', 'tricep Pushdown', 'deadlift', 'shoulder press']
# Current Top1: 48.717948717948715 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/chest fly machine/chest fly machine_1_0.mp4
# chest fly machine
# ['shoulder press', 'chest fly machine', 'squat', 'lat pulling', 'tricep dips']
# Current Top1: 48.10126582278481 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/chest fly machine/chest fly machine_1_1.mp4
# chest fly machine
# ['shoulder press', 'squat', 'chest fly machine', 'lat pulling', 'tricep dips']
# Current Top1: 47.5 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/chest fly machine/chest fly machine_4_0.mp4
# chest fly machine
# ['shoulder press', 'tricep Pushdown', 'deadlift', 'chest fly machine', 'squat']
# Current Top1: 46.913580246913575 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/chest fly machine/chest fly machine_4_1.mp4
# chest fly machine
# ['shoulder press', 'chest fly machine', 'tricep Pushdown', 'squat', 'deadlift']
# Current Top1: 47.5609756097561 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/chest fly machine/chest fly machine_9_0.mp4
# chest fly machine
# ['chest fly machine', 'shoulder press', 'bench press', 'tricep Pushdown', 'leg raises']
# Current Top1: 48.19277108433735 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/chest fly machine/chest fly machine_9_1.mp4
# chest fly machine
# ['chest fly machine', 'shoulder press', 'lat pulling', 'tricep Pushdown', 'bench press']
# Current Top1: 47.61904761904761 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/chest fly machine/chest fly machine_25_0.mp4
# chest fly machine
# ['hip thrust', 'lat pulling', 'lateral raise', 'bench press', 't bar row']
# Current Top1: 47.05882352941176 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/chest fly machine/chest fly machine_25_1.mp4
# chest fly machine
# ['hip thrust', 't bar row', 'tricep dips', 'lat pulling', 'bench press']
# Current Top1: 46.51162790697674 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/chest fly machine/chest fly machine_25_2.mp4
# chest fly machine
# ['hip thrust', 'lat pulling', 'tricep dips', 'lateral raise', 'bench press']
# Current Top1: 45.97701149425287 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/chest fly machine/chest fly machine_25_3.mp4
# chest fly machine
# ['hip thrust', 'lat pulling', 'bench press', 'tricep dips', 'lateral raise']
# Current Top1: 45.45454545454545 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/chest fly machine/chest fly machine_14_0.mp4
# chest fly machine
# ['tricep dips', 'lat pulling', 'hip thrust', 'tricep Pushdown', 'deadlift']
# Current Top1: 44.9438202247191 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/hip thrust/hip thrust_1_0.MOV
# hip thrust
# ['bench press', 'hip thrust', 'chest fly machine', 'tricep Pushdown', 'leg raises']
# Current Top1: 44.44444444444444 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/hip thrust/hip thrust_1_1.MOV
# hip thrust
# ['bench press', 'chest fly machine', 'hip thrust', 'lat pulling', 'tricep Pushdown']
# Current Top1: 43.956043956043956 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/hip thrust/hip thrust_1_2.MOV
# hip thrust
# ['bench press', 'hip thrust', 'chest fly machine', 'tricep Pushdown', 'leg raises']
# Current Top1: 43.47826086956522 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/hip thrust/hip thrust_1_3.MOV
# hip thrust
# ['bench press', 'chest fly machine', 'hip thrust', 'tricep Pushdown', 'lat pulling']
# Current Top1: 43.01075268817204 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/hip thrust/hip thrust_1_4.MOV
# hip thrust
# ['bench press', 'chest fly machine', 'hip thrust', 'lat pulling', 'tricep Pushdown']
# Current Top1: 42.5531914893617 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/hip thrust/hip thrust_1_5.MOV
# hip thrust
# ['bench press', 'hip thrust', 'chest fly machine', 'tricep Pushdown', 'lat pulling']
# Current Top1: 42.10526315789473 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/hip thrust/hip thrust_1_6.MOV
# hip thrust
# ['bench press', 'chest fly machine', 'hip thrust', 'tricep Pushdown', 'lat pulling']
# Current Top1: 41.66666666666667 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/hip thrust/hip thrust_13_0.mp4
# hip thrust
# ['deadlift', 'bench press', 'hip thrust', 'bicep curl', 'russian twist']
# Current Top1: 42.2680412371134 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/hip thrust/hip thrust_13_1.mp4
# hip thrust
# ['hip thrust', 'deadlift', 'bench press', 'bicep curl', 'russian twist']
# Current Top1: 42.857142857142854 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/hip thrust/hip thrust_10_0.mp4
# hip thrust
# ['hip thrust', 'lat pulling', 'bench press', 'lateral raise', 'deadlift']
# Current Top1: 43.43434343434344 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/hip thrust/hip thrust_10_1.mp4
# hip thrust
# ['hip thrust', 'bench press', 'lat pulling', 'lateral raise', 'tricep Pushdown']
# Current Top1: 44.0 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/hip thrust/hip thrust_10_2.mp4
# hip thrust
# ['hip thrust', 'bench press', 'lat pulling', 'lateral raise', 'tricep Pushdown']
# Current Top1: 44.554455445544555 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/hip thrust/hip thrust_10_3.mp4
# hip thrust
# ['hip thrust', 'bench press', 'lat pulling', 'lateral raise', 'tricep Pushdown']
# Current Top1: 45.09803921568628 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/hip thrust/hip thrust_10_4.mp4
# hip thrust
# ['hip thrust', 'bench press', 'lat pulling', 'tricep Pushdown', 'lateral raise']
# Current Top1: 45.63106796116505 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/hip thrust/hip thrust_10_5.mp4
# hip thrust
# ['hip thrust', 'bench press', 'lat pulling', 'lateral raise', 'tricep Pushdown']
# Current Top1: 45.19230769230769 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/hip thrust/hip thrust_11_0.mp4
# hip thrust
# ['push-up', 'hip thrust', 'lat pulling', 'deadlift', 'bench press']
# Current Top1: 44.761904761904766 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/deadlift/deadlift_25_0.mp4
# deadlift
# ['tricep dips', 'shoulder press', 'lat pulling', 'squat', 'tricep Pushdown']
# Current Top1: 44.339622641509436 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/deadlift/deadlift_25_1.mp4
# deadlift
# ['tricep Pushdown', 'tricep dips', 'shoulder press', 'lat pulling', 'chest fly machine']
# Current Top1: 43.925233644859816 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/deadlift/deadlift_25_2.mp4
# deadlift
# ['chest fly machine', 'shoulder press', 'tricep dips', 'tricep Pushdown', 'lat pulling']
# Current Top1: 43.51851851851852 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/deadlift/deadlift_25_3.mp4
# deadlift
# ['shoulder press', 'chest fly machine', 'tricep dips', 'tricep Pushdown', 'lat pulling']
# Current Top1: 43.11926605504588 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/deadlift/deadlift_25_4.mp4
# deadlift
# ['lat pulling', 'chest fly machine', 'shoulder press', 'tricep Pushdown', 'tricep dips']
# Current Top1: 42.72727272727273 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/deadlift/deadlift_25_5.mp4
# deadlift
# ['tricep Pushdown', 'chest fly machine', 'lat pulling', 'shoulder press', 'tricep dips']
# Current Top1: 42.34234234234234 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/deadlift/deadlift_25_6.mp4
# deadlift
# ['chest fly machine', 'tricep Pushdown', 'bench press', 'shoulder press', 'lat pulling']
# Current Top1: 41.964285714285715 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/deadlift/deadlift_25_7.mp4
# deadlift
# ['tricep Pushdown', 'chest fly machine', 'lat pulling', 'shoulder press', 'deadlift']
# Current Top1: 41.5929203539823 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/deadlift/deadlift_25_8.mp4
# deadlift
# ['chest fly machine', 'tricep Pushdown', 'shoulder press', 'lat pulling', 'bench press']
# Current Top1: 41.228070175438596 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/deadlift/deadlift_25_9.mp4
# deadlift
# ['tricep Pushdown', 'chest fly machine', 'shoulder press', 'lat pulling', 'leg extension']
# Current Top1: 40.869565217391305 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/deadlift/deadlift_25_10.mp4
# deadlift
# ['tricep Pushdown', 'chest fly machine', 'shoulder press', 'lat pulling', 'tricep dips']
# Current Top1: 40.51724137931034 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/deadlift/deadlift_25_11.mp4
# deadlift
# ['tricep Pushdown', 'shoulder press', 'chest fly machine', 'tricep dips', 'lat pulling']
# Current Top1: 40.17094017094017 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/deadlift/deadlift_25_12.mp4
# deadlift
# ['chest fly machine', 'tricep Pushdown', 'shoulder press', 'bench press', 'hip thrust']
# Current Top1: 39.83050847457627 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/deadlift/deadlift_25_13.mp4
# deadlift
# ['shoulder press', 'tricep Pushdown', 'chest fly machine', 'bench press', 'hip thrust']
# Current Top1: 39.49579831932773 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/deadlift/deadlift_25_14.mp4
# deadlift
# ['tricep Pushdown', 'chest fly machine', 'shoulder press', 'bench press', 'lat pulling']
# Current Top1: 39.166666666666664 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/deadlift/deadlift_25_15.mp4
# deadlift
# ['hip thrust', 'shoulder press', 'tricep dips', 't bar row', 'chest fly machine']
# Current Top1: 38.84297520661157 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/deadlift/deadlift_25_16.mp4
# deadlift
# ['tricep dips', 'shoulder press', 'hip thrust', 'lat pulling', 'chest fly machine']
# Current Top1: 38.52459016393443 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/deadlift/deadlift_25_17.mp4
# deadlift
# ['bench press', 'tricep Pushdown', 'lat pulling', 'squat', 'chest fly machine']
# Current Top1: 38.21138211382114 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/deadlift/deadlift_25_18.mp4
# deadlift
# ['tricep Pushdown', 'chest fly machine', 'deadlift', 'shoulder press', 'lat pulling']
# Current Top1: 37.903225806451616 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/deadlift/deadlift_31_0.mp4
# deadlift
# ['tricep Pushdown', 'chest fly machine', 'bench press', 'shoulder press', 'lat pulling']
# Current Top1: 37.6 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/deadlift/deadlift_31_1.mp4
# deadlift
# ['bench press', 'chest fly machine', 'tricep Pushdown', 'shoulder press', 'lat pulling']
# Current Top1: 37.301587301587304 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/deadlift/deadlift_31_2.mp4
# deadlift
# ['bench press', 'tricep Pushdown', 'chest fly machine', 'shoulder press', 'lat pulling']
# Current Top1: 37.00787401574803 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/deadlift/deadlift_27_0.mp4
# deadlift
# ['tricep Pushdown', 'bench press', 'chest fly machine', 'lat pulling', 'deadlift']
# Current Top1: 36.71875 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/deadlift/deadlift_27_1.mp4
# deadlift
# ['tricep Pushdown', 'chest fly machine', 'bench press', 'deadlift', 'lat pulling']
# Current Top1: 36.434108527131784 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/deadlift/deadlift_27_2.mp4
# deadlift
# ['tricep Pushdown', 'deadlift', 'lat pulling', 'chest fly machine', 'bench press']
# Current Top1: 36.15384615384615 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/deadlift/deadlift_26_0.mp4
# deadlift
# ['bench press', 'tricep Pushdown', 'chest fly machine', 'lat pulling', 'shoulder press']
# Current Top1: 35.87786259541985 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/deadlift/deadlift_26_1.mp4
# deadlift
# ['bench press', 'tricep Pushdown', 'chest fly machine', 'shoulder press', 'lat pulling']
# Current Top1: 35.60606060606061 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/deadlift/deadlift_26_2.mp4
# deadlift
# ['bench press', 'tricep Pushdown', 'chest fly machine', 'lat pulling', 'shoulder press']
# Current Top1: 36.09022556390977 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/deadlift/deadlift_3_0.mp4
# deadlift
# ['deadlift', 'push-up', 'tricep dips', 'russian twist', 'lat pulling']
# Current Top1: 36.56716417910448 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/deadlift/deadlift_3_1.mp4
# deadlift
# ['deadlift', 'push-up', 'tricep dips', 'russian twist', 'lat pulling']
# Current Top1: 36.2962962962963 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/deadlift/deadlift_30_0.mp4
# deadlift
# ['tricep Pushdown', 'deadlift', 'chest fly machine', 'bench press', 'lat pulling']
# Current Top1: 36.029411764705884 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/deadlift/deadlift_30_1.mp4
# deadlift
# ['chest fly machine', 'tricep Pushdown', 'deadlift', 'shoulder press', 'bench press']
# Current Top1: 35.76642335766424 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/deadlift/deadlift_30_2.mp4
# deadlift
# ['tricep Pushdown', 'chest fly machine', 'deadlift', 'shoulder press', 'lat pulling']
# Current Top1: 35.507246376811594 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/deadlift/romanian deadlift_1_0.mov
# deadlift
# ['chest fly machine', 'tricep Pushdown', 'leg raises', 'bench press', 'shoulder press']
# Current Top1: 35.25179856115108 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/deadlift/romanian deadlift_1_1.mov
# deadlift
# ['bench press', 'chest fly machine', 'leg raises', 'tricep Pushdown', 'shoulder press']
# Current Top1: 35.0 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/deadlift/romanian deadlift_1_2.mov
# deadlift
# ['chest fly machine', 'tricep Pushdown', 'leg raises', 'bench press', 'shoulder press']
# Current Top1: 34.751773049645394 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/deadlift/romanian deadlift_1_3.mov
# deadlift
# ['chest fly machine', 'bench press', 'leg raises', 'tricep Pushdown', 'shoulder press']
# Current Top1: 34.50704225352113 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/deadlift/romanian deadlift_1_4.mov
# deadlift
# ['bench press', 'chest fly machine', 'leg raises', 'tricep Pushdown', 'shoulder press']
# Current Top1: 34.26573426573427 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/deadlift/romanian deadlift_1_5.mov
# deadlift
# ['chest fly machine', 'tricep Pushdown', 'leg raises', 'bench press', 'shoulder press']
# Current Top1: 34.72222222222222 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/deadlift/romanian deadlift_11_0.mp4
# deadlift
# ['deadlift', 'tricep Pushdown', 'chest fly machine', 'shoulder press', 'leg extension']
# Current Top1: 35.172413793103445 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/deadlift/romanian deadlift_11_1.mp4
# deadlift
# ['deadlift', 'tricep Pushdown', 'chest fly machine', 'shoulder press', 'squat']
# Current Top1: 34.93150684931507 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/deadlift/romanian deadlift_2_0.MOV
# deadlift
# ['chest fly machine', 'leg raises', 'tricep Pushdown', 'bench press', 'lat pulling']
# Current Top1: 34.69387755102041 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/deadlift/romanian deadlift_2_1.MOV
# deadlift
# ['bench press', 'chest fly machine', 'leg raises', 'tricep Pushdown', 'lat pulling']
# Current Top1: 34.45945945945946 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/deadlift/romanian deadlift_2_2.MOV
# deadlift
# ['chest fly machine', 'leg raises', 'bench press', 'tricep Pushdown', 'shoulder press']
# Current Top1: 34.22818791946309 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/deadlift/romanian deadlift_2_3.MOV
# deadlift
# ['chest fly machine', 'leg raises', 'bench press', 'tricep Pushdown', 'lat pulling']
# Current Top1: 34.0 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/deadlift/romanian deadlift_2_4.MOV
# deadlift
# ['bench press', 'leg raises', 'chest fly machine', 'tricep Pushdown', 'shoulder press']
# Current Top1: 33.77483443708609 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/deadlift/romanian deadlift_2_5.MOV
# deadlift
# ['chest fly machine', 'leg raises', 'bench press', 'tricep Pushdown', 'shoulder press']
# Current Top1: 33.55263157894737 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/deadlift/romanian deadlift_2_6.MOV
# deadlift
# ['bench press', 'chest fly machine', 'leg raises', 'tricep Pushdown', 'lat pulling']
# Current Top1: 33.33333333333333 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/deadlift/romanian deadlift_2_7.MOV
# deadlift
# ['chest fly machine', 'bench press', 'leg raises', 'tricep Pushdown', 'shoulder press']
# Current Top1: 33.76623376623377 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/leg extension/leg extension_19_0.mp4
# leg extension
# ['leg extension', 'squat', 'shoulder press', 'tricep Pushdown', 'chest fly machine']
# Current Top1: 33.5483870967742 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/leg extension/leg extension_12_0.mp4
# leg extension
# ['tricep Pushdown', 'leg extension', 'deadlift', 'chest fly machine', 'shoulder press']
# Current Top1: 33.33333333333333 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/leg extension/leg extension_12_1.mp4
# leg extension
# ['tricep Pushdown', 'leg extension', 'deadlift', 'chest fly machine', 'shoulder press']
# Current Top1: 33.12101910828025 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/leg extension/leg extension_3_0.MOV
# leg extension
# ['tricep Pushdown', 'shoulder press', 'squat', 'leg extension', 'bench press']
# Current Top1: 32.91139240506329 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/leg extension/leg extension_3_1.MOV
# leg extension
# ['tricep Pushdown', 'shoulder press', 'bench press', 'leg extension', 'chest fly machine']
# Current Top1: 32.70440251572327 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/leg extension/leg extension_3_2.MOV
# leg extension
# ['shoulder press', 'tricep Pushdown', 'leg extension', 'squat', 'chest fly machine']
# Current Top1: 32.5 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/leg extension/leg extension_3_3.MOV
# leg extension
# ['shoulder press', 'leg extension', 'tricep Pushdown', 'squat', 'chest fly machine']
# Current Top1: 32.298136645962735 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/leg extension/leg extension_3_4.MOV
# leg extension
# ['shoulder press', 'tricep Pushdown', 'lat pulling', 'tricep dips', 'chest fly machine']
# Current Top1: 32.098765432098766 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/leg extension/leg extension_3_5.MOV
# leg extension
# ['tricep Pushdown', 'shoulder press', 'bench press', 'chest fly machine', 'lat pulling']
# Current Top1: 31.901840490797547 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/leg extension/leg extension_10_0.mp4
# leg extension
# ['tricep Pushdown', 'push-up', 'squat', 'shoulder press', 'lat pulling']
# Current Top1: 31.70731707317073 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/leg extension/leg extension_10_1.mp4
# leg extension
# ['squat', 'tricep Pushdown', 'deadlift', 'lateral raise', 'shoulder press']
# Current Top1: 32.121212121212125 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/leg extension/leg extension_10_2.mp4
# leg extension
# ['leg extension', 'squat', 'tricep Pushdown', 'deadlift', 'lateral raise']
# Current Top1: 31.92771084337349 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/leg extension/leg extension_18_0.mp4
# leg extension
# ['chest fly machine', 'tricep Pushdown', 'leg raises', 'shoulder press', 'bench press']
# Current Top1: 31.736526946107784 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/leg extension/leg extension_18_1.mp4
# leg extension
# ['chest fly machine', 'leg raises', 'tricep Pushdown', 'shoulder press', 'bench press']
# Current Top1: 31.547619047619047 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/leg extension/leg extension_18_2.mp4
# leg extension
# ['chest fly machine', 'leg raises', 'tricep Pushdown', 'shoulder press', 'bench press']
# Current Top1: 31.360946745562128 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/leg extension/leg extension_18_3.mp4
# leg extension
# ['chest fly machine', 'tricep Pushdown', 'leg raises', 'shoulder press', 'bench press']
# Current Top1: 31.176470588235293 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/leg extension/leg extension_18_4.mp4
# leg extension
# ['chest fly machine', 'tricep Pushdown', 'leg raises', 'shoulder press', 'bench press']
# Current Top1: 30.994152046783626 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/leg extension/leg extension_18_5.mp4
# leg extension
# ['chest fly machine', 'tricep Pushdown', 'shoulder press', 'leg raises', 'bench press']
# Current Top1: 30.813953488372093 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/leg extension/leg extension_18_6.mp4
# leg extension
# ['chest fly machine', 'tricep Pushdown', 'leg raises', 'shoulder press', 'bench press']
# Current Top1: 30.63583815028902 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/leg extension/leg extension_18_7.mp4
# leg extension
# ['chest fly machine', 'tricep Pushdown', 'leg raises', 'shoulder press', 'bench press']
# Current Top1: 30.45977011494253 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/push-up/push-up_20_0.mp4
# push-up
# ['russian twist', 'tricep Pushdown', 'chest fly machine', 'shoulder press', 'push-up']
# Current Top1: 30.28571428571429 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/push-up/push-up_20_1.mp4
# push-up
# ['tricep Pushdown', 'russian twist', 'chest fly machine', 'shoulder press', 'push-up']
# Current Top1: 30.113636363636363 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/push-up/push-up_56_0.mp4
# push-up
# ['t bar row', 'lateral raise', 'hip thrust', 'bicep curl', 'chest fly machine']
# Current Top1: 29.943502824858758 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/push-up/push-up_56_1.mp4
# push-up
# ['t bar row', 'lateral raise', 'hip thrust', 'chest fly machine', 'bicep curl']
# Current Top1: 29.775280898876407 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/push-up/push-up_56_2.mp4
# push-up
# ['t bar row', 'lateral raise', 'hip thrust', 'bicep curl', 'chest fly machine']
# Current Top1: 29.608938547486037 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/push-up/push-up_56_3.mp4
# push-up
# ['t bar row', 'lateral raise', 'hip thrust', 'chest fly machine', 'bicep curl']
# Current Top1: 29.444444444444446 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/push-up/push-up_56_4.mp4
# push-up
# ['t bar row', 'lateral raise', 'hip thrust', 'bicep curl', 'chest fly machine']
# Current Top1: 29.2817679558011 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/push-up/push-up_56_5.mp4
# push-up
# ['t bar row', 'lateral raise', 'hip thrust', 'chest fly machine', 'deadlift']
# Current Top1: 29.120879120879124 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/push-up/push-up_56_6.mp4
# push-up
# ['t bar row', 'lateral raise', 'hip thrust', 'bicep curl', 'chest fly machine']
# Current Top1: 28.96174863387978 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/push-up/push-up_56_7.mp4
# push-up
# ['t bar row', 'lateral raise', 'hip thrust', 'bicep curl', 'chest fly machine']
# Current Top1: 28.804347826086957 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/push-up/push-up_56_8.mp4
# push-up
# ['t bar row', 'lateral raise', 'hip thrust', 'bicep curl', 'deadlift']
# Current Top1: 29.18918918918919 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/push-up/push-up_13_0.mp4
# push-up
# ['push-up', 'russian twist', 'deadlift', 'lateral raise', 'bicep curl']
# Current Top1: 29.56989247311828 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/push-up/push-up_13_1.mp4
# push-up
# ['push-up', 'russian twist', 'deadlift', 'lateral raise', 'tricep dips']
# Current Top1: 29.946524064171122 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/push-up/push-up_1_0.mp4
# push-up
# ['push-up', 'deadlift', 'russian twist', 'bicep curl', 'lat pulling']
# Current Top1: 30.319148936170215 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/push-up/push-up_1_1.mp4
# push-up
# ['push-up', 'deadlift', 'russian twist', 'bicep curl', 'lat pulling']
# Current Top1: 30.687830687830687 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/push-up/push-up_53_0.mp4
# push-up
# ['push-up', 'lat pulling', 'chest fly machine', 'shoulder press', 'squat']
# Current Top1: 31.05263157894737 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/push-up/push-up_53_1.mp4
# push-up
# ['push-up', 'shoulder press', 'lat pulling', 'chest fly machine', 'squat']
# Current Top1: 31.413612565445025 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/push-up/push-up_53_2.mp4
# push-up
# ['push-up', 'chest fly machine', 'lat pulling', 'shoulder press', 'squat']
# Current Top1: 31.770833333333332 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/push-up/push-up_53_3.mp4
# push-up
# ['push-up', 'lat pulling', 'shoulder press', 'chest fly machine', 'squat']
# Current Top1: 32.12435233160622 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/push-up/push-up_53_4.mp4
# push-up
# ['push-up', 'lat pulling', 'shoulder press', 'tricep dips', 'squat']
# Current Top1: 32.47422680412371 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/push-up/push-up_53_5.mp4
# push-up
# ['push-up', 'lat pulling', 'shoulder press', 'squat', 'tricep dips']
# Current Top1: 32.82051282051282 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/push-up/push-up_53_6.mp4
# push-up
# ['push-up', 'lat pulling', 'squat', 'shoulder press', 'tricep dips']
# Current Top1: 32.6530612244898 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/push-up/push-up_53_7.mp4
# push-up
# ['lat pulling', 'push-up', 'squat', 'chest fly machine', 'shoulder press']
# Current Top1: 32.99492385786802 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/push-up/push-up_53_8.mp4
# push-up
# ['push-up', 'lat pulling', 'squat', 'tricep dips', 'deadlift']
# Current Top1: 33.33333333333333 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/push-up/push-up_53_9.mp4
# push-up
# ['push-up', 'squat', 'deadlift', 't bar row', 'lateral raise']
# Current Top1: 33.66834170854271 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/push-up/push-up_53_10.mp4
# push-up
# ['push-up', 'squat', 'deadlift', 't bar row', 'lateral raise']
# Current Top1: 34.0 %
# ...
# bicep curl
# ['push-up', 'tricep dips', 'deadlift', 'lat pulling', 'squat']
# Current Top1: 38.7434554973822 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/bicep curl/barbell biceps curl_45_2.mp4
# bicep curl
# ['tricep dips', 'push-up', 'deadlift', 'lat pulling', 'squat']
# Current Top1: 38.642297650130544 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/bicep curl/barbell biceps curl_45_3.mp4
# bicep curl
# ['tricep dips', 'push-up', 'deadlift', 'lat pulling', 'squat']
# Current Top1: 38.54166666666667 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/bicep curl/barbell biceps curl_45_4.mp4
# bicep curl
# ['push-up', 'tricep dips', 'deadlift', 'lat pulling', 'squat']
# Current Top1: 38.44155844155844 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/bicep curl/barbell biceps curl_45_5.mp4
# bicep curl
# ['push-up', 'tricep dips', 'deadlift', 'lat pulling', 'squat']
# Current Top1: 38.34196891191709 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/bicep curl/barbell biceps curl_45_6.mp4
# bicep curl
# ['push-up', 'tricep dips', 'deadlift', 'lat pulling', 'squat']
# Current Top1: 38.24289405684754 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/bicep curl/barbell biceps curl_61_0.mp4
# bicep curl
# ['deadlift', 'leg extension', 'squat', 'tricep Pushdown', 'shoulder press']
# Current Top1: 38.144329896907216 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/bicep curl/barbell biceps curl_3_0.mp4
# bicep curl
# ['t bar row', 'chest fly machine', 'lat pulling', 'russian twist', 'shoulder press']
# Current Top1: 38.303341902313626 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/bicep curl/barbell biceps curl_32_0.mp4
# bicep curl
# ['bicep curl', 'lat pulling', 'tricep Pushdown', 'tricep dips', 'shoulder press']
# Current Top1: 38.46153846153847 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/bicep curl/barbell biceps curl_24_0.mp4
# bicep curl
# ['bicep curl', 'hip thrust', 'chest fly machine', 'lateral raise', 'tricep Pushdown']
# Current Top1: 38.36317135549872 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/bicep curl/barbell biceps curl_31_0.mp4
# bicep curl
# ['lat pulling', 'bicep curl', 'shoulder press', 'tricep Pushdown', 'chest fly machine']
# Current Top1: 38.265306122448976 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/bicep curl/barbell biceps curl_14_0.mp4
# bicep curl
# ['lat pulling', 'bicep curl', 'tricep Pushdown', 'shoulder press', 'chest fly machine']
# Current Top1: 38.16793893129771 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/bicep curl/barbell biceps curl_9_0.mp4
# bicep curl
# ['squat', 'leg extension', 'deadlift', 'chest fly machine', 'shoulder press']
# Current Top1: 38.07106598984771 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/bicep curl/barbell biceps curl_7_0.mp4
# bicep curl
# ['squat', 'chest fly machine', 'leg extension', 'deadlift', 'lateral raise']
# Current Top1: 37.9746835443038 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/bicep curl/barbell biceps curl_7_1.mp4
# bicep curl
# ['squat', 'deadlift', 'chest fly machine', 'shoulder press', 'tricep Pushdown']
# Current Top1: 37.878787878787875 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/bicep curl/barbell biceps curl_41_0.mp4
# bicep curl
# ['push-up', 'lat pulling', 'tricep dips', 'bicep curl', 'deadlift']
# Current Top1: 37.78337531486146 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/bicep curl/barbell biceps curl_41_1.mp4
# bicep curl
# ['lat pulling', 'tricep dips', 'push-up', 'bicep curl', 'squat']
# Current Top1: 37.68844221105528 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/bicep curl/barbell biceps curl_41_2.mp4
# bicep curl
# ['tricep dips', 'push-up', 'bicep curl', 'lat pulling', 'deadlift']
# Current Top1: 37.84461152882205 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/bicep curl/hammer curl_15_0.mp4
# bicep curl
# ['bicep curl', 'tricep Pushdown', 'push-up', 'chest fly machine', 'lat pulling']
# Current Top1: 37.75 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/bicep curl/hammer curl_5_0.MOV
# bicep curl
# ['lat pulling', 'shoulder press', 'leg raises', 'bench press', 'chest fly machine']
# Current Top1: 37.65586034912718 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/bicep curl/hammer curl_5_1.MOV
# bicep curl
# ['bench press', 'leg raises', 'shoulder press', 'chest fly machine', 'hip thrust']
# Current Top1: 37.56218905472637 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/bicep curl/hammer curl_5_2.MOV
# bicep curl
# ['leg raises', 'shoulder press', 'lat pulling', 'bench press', 'hip thrust']
# Current Top1: 37.468982630272954 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/bicep curl/hammer curl_5_3.MOV
# bicep curl
# ['leg raises', 'russian twist', 'hip thrust', 'bench press', 'shoulder press']
# Current Top1: 37.37623762376238 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/bicep curl/hammer curl_5_4.MOV
# bicep curl
# ['russian twist', 'leg raises', 'hip thrust', 'shoulder press', 'bench press']
# Current Top1: 37.28395061728395 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/bicep curl/hammer curl_5_5.MOV
# bicep curl
# ['leg raises', 'russian twist', 'hip thrust', 'shoulder press', 'squat']
# Current Top1: 37.19211822660098 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/bicep curl/hammer curl_5_6.MOV
# bicep curl
# ['shoulder press', 'russian twist', 'leg raises', 'chest fly machine', 'tricep dips']
# Current Top1: 37.1007371007371 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/bicep curl/hammer curl_10_0.mp4
# bicep curl
# ['lat pulling', 'bench press', 'tricep Pushdown', 'hip thrust', 'tricep dips']
# Current Top1: 37.00980392156863 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/bicep curl/hammer curl_9_0.mp4
# bicep curl
# ['tricep Pushdown', 'russian twist', 'lat pulling', 'squat', 'bicep curl']
# Current Top1: 36.91931540342298 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/bicep curl/hammer curl_9_1.mp4
# bicep curl
# ['lat pulling', 'russian twist', 'tricep Pushdown', 'bench press', 'bicep curl']
# Current Top1: 37.073170731707314 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lat pulling/lat pulldown_31_0.mp4
# lat pulling
# ['lat pulling', 'bench press', 'push-up', 'tricep dips', 't bar row']
# Current Top1: 37.22627737226277 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lat pulling/lat pulldown_31_1.mp4
# lat pulling
# ['lat pulling', 'bench press', 'deadlift', 'hip thrust', 'tricep dips']
# Current Top1: 37.37864077669903 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lat pulling/lat pulldown_21_0.mp4
# lat pulling
# ['lat pulling', 'chest fly machine', 'tricep dips', 'shoulder press', 'russian twist']
# Current Top1: 37.530266343825666 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lat pulling/lat pulldown_4_0.mp4
# lat pulling
# ['lat pulling', 'chest fly machine', 'bench press', 'shoulder press', 'tricep dips']
# Current Top1: 37.68115942028986 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lat pulling/lat pulldown_44_0.mp4
# lat pulling
# ['lat pulling', 'deadlift', 'tricep dips', 'tricep Pushdown', 'hip thrust']
# Current Top1: 37.83132530120482 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lat pulling/lat pulldown_12_0.mp4
# lat pulling
# ['lat pulling', 'lateral raise', 'hip thrust', 'leg raises', 'shoulder press']
# Current Top1: 37.980769230769226 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lat pulling/lat pulldown_12_1.mp4
# lat pulling
# ['lat pulling', 'lateral raise', 'hip thrust', 'leg raises', 'bench press']
# Current Top1: 38.1294964028777 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lat pulling/lat pulldown_9_0.mp4
# lat pulling
# ['lat pulling', 'lateral raise', 'hip thrust', 'leg raises', 'shoulder press']
# Current Top1: 38.27751196172249 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lat pulling/lat pulldown_40_0.mp4
# lat pulling
# ['lat pulling', 'chest fly machine', 'leg raises', 'shoulder press', 'bicep curl']
# Current Top1: 38.18615751789976 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lat pulling/lat pulldown_40_1.mp4
# lat pulling
# ['chest fly machine', 'lat pulling', 'leg raises', 'shoulder press', 'bicep curl']
# Current Top1: 38.333333333333336 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lat pulling/lat pulldown_40_2.mp4
# lat pulling
# ['lat pulling', 'chest fly machine', 'leg raises', 'bicep curl', 'shoulder press']
# Current Top1: 38.47980997624703 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lat pulling/lat pulldown_40_3.mp4
# lat pulling
# ['lat pulling', 'chest fly machine', 'bicep curl', 'leg raises', 'shoulder press']
# Current Top1: 38.62559241706161 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lat pulling/lat pulldown_40_4.mp4
# lat pulling
# ['lat pulling', 'bicep curl', 'chest fly machine', 'deadlift', 'leg raises']
# Current Top1: 38.77068557919622 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lat pulling/lat pulldown_38_0.mp4
# lat pulling
# ['lat pulling', 'hip thrust', 'bicep curl', 'lateral raise', 'chest fly machine']
# Current Top1: 38.91509433962264 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lat pulling/lat pulldown_38_1.mp4
# lat pulling
# ['lat pulling', 'hip thrust', 'bicep curl', 'lateral raise', 'chest fly machine']
# Current Top1: 39.05882352941176 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lat pulling/lat pulldown_24_0.mp4
# lat pulling
# ['lat pulling', 'russian twist', 'tricep dips', 'tricep Pushdown', 'squat']
# Current Top1: 39.201877934272304 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lat pulling/lat pulldown_25_0.mp4
# lat pulling
# ['lat pulling', 'tricep dips', 'tricep Pushdown', 'hip thrust', 'lateral raise']
# Current Top1: 39.34426229508197 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lat pulling/pull up_25_0.mp4
# lat pulling
# ['lat pulling', 'push-up', 't bar row', 'bicep curl', 'tricep dips']
# Current Top1: 39.48598130841122 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lat pulling/pull up_21_0.mp4
# lat pulling
# ['lat pulling', 'tricep Pushdown', 'tricep dips', 'shoulder press', 'chest fly machine']
# Current Top1: 39.62703962703963 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lat pulling/pull up_21_1.mp4
# lat pulling
# ['lat pulling', 'tricep dips', 'squat', 'shoulder press', 'tricep Pushdown']
# Current Top1: 39.76744186046511 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lat pulling/pull up_21_2.mp4
# lat pulling
# ['lat pulling', 'tricep dips', 'squat', 'shoulder press', 'tricep Pushdown']
# Current Top1: 39.90719257540603 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lat pulling/pull up_21_3.mp4
# lat pulling
# ['lat pulling', 'tricep dips', 'squat', 'tricep Pushdown', 'shoulder press']
# Current Top1: 40.0462962962963 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lat pulling/pull up_6_0.mp4
# lat pulling
# ['lat pulling', 'hip thrust', 'deadlift', 'bench press', 'chest fly machine']
# Current Top1: 40.184757505773675 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lat pulling/pull up_6_1.mp4
# lat pulling
# ['lat pulling', 'hip thrust', 'deadlift', 'bench press', 'chest fly machine']
# Current Top1: 40.32258064516129 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lat pulling/pull up_6_2.mp4
# lat pulling
# ['lat pulling', 'hip thrust', 'deadlift', 'bench press', 'chest fly machine']
# Current Top1: 40.45977011494253 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lat pulling/pull up_6_3.mp4
# lat pulling
# ['lat pulling', 'hip thrust', 'deadlift', 'bench press', 'chest fly machine']
# Current Top1: 40.596330275229356 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lat pulling/pull up_6_4.mp4
# lat pulling
# ['lat pulling', 'hip thrust', 'deadlift', 'bench press', 'chest fly machine']
# Current Top1: 40.503432494279174 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lat pulling/pull up_13_0.mp4
# lat pulling
# ['deadlift', 'lat pulling', 'chest fly machine', 'squat', 'tricep Pushdown']
# Current Top1: 40.41095890410959 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lat pulling/pull up_13_1.mp4
# lat pulling
# ['deadlift', 'lat pulling', 'squat', 'chest fly machine', 'tricep Pushdown']
# Current Top1: 40.31890660592255 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lat pulling/pull up_13_2.mp4
# lat pulling
# ['deadlift', 'lat pulling', 'chest fly machine', 'squat', 'tricep Pushdown']
# Current Top1: 40.45454545454545 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lat pulling/pull up_13_3.mp4
# lat pulling
# ['lat pulling', 'deadlift', 'squat', 'chest fly machine', 'push-up']
# Current Top1: 40.362811791383216 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lat pulling/pull up_13_4.mp4
# lat pulling
# ['deadlift', 'lat pulling', 'chest fly machine', 'squat', 'tricep Pushdown']
# Current Top1: 40.497737556561084 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lat pulling/pull up_13_5.mp4
# lat pulling
# ['lat pulling', 'deadlift', 'squat', 'chest fly machine', 'push-up']
# Current Top1: 40.63205417607224 %
# /content/drive/MyDrive/Research/Muscle Video/Datasets/split_workout_videos_v1/test/lat pulling/pull up_24_0.mp4
# lat pulling
# ['lat pulling', 'push-up', 'bicep curl', 't bar row', 'tricep dips']
# Evaluation Finished
# Top 1 Accuracy: 40.63205417607224 %
# Top 5 Accuracy: 64.55981941309255 %
# {'bench press': 51.35135135135135, 'bicep curl': 10.0, 'chest fly machine': 50.0, 'deadlift': 8.16326530612245, 'hip thrust': 43.75, 'lat pulling': 85.29411764705883, 'lateral raise': 36.36363636363637, 'leg extension': 10.0, 'leg raises': 29.411764705882355, 'push-up': 57.89473684210527, 'russian twist': 42.10526315789473, 'shoulder press': 13.043478260869565, 'squat': 43.58974358974359, 't bar row': 25.0, 'tricep Pushdown': 76.47058823529412, 'tricep dips': 80.0}
# {'bench press': 83.78378378378379, 'bicep curl': 33.33333333333333, 'chest fly machine': 72.22222222222221, 'deadlift': 24.489795918367346, 'hip thrust': 100.0, 'lat pulling': 100.0, 'lateral raise': 66.66666666666666, 'leg extension': 40.0, 'leg raises': 41.17647058823529, 'push-up': 76.31578947368422, 'russian twist': 100.0, 'shoulder press': 30.434782608695656, 'squat': 71.7948717948718, 't bar row': 32.142857142857146, 'tricep Pushdown': 94.11764705882352, 'tricep dips': 100.0}
